# %% [markdown]
# # VacationPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import gmaps
import os
from spaghetti import q_key

# %% [markdown]
# ### Store Part I results into DataFrame
# * Load the csv exported in Part I to a DataFrame

# %%
weather=pd.read_csv('weath_er.csv')
weath_er=weather.drop(['Unnamed: 0'], axis=1)
weath_er.head(2)
# Out:
#           City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 0  Tuktoyaktuk          90      CA  1580836288        75  69.45 -133.04
# 1     Umm Lajj           0      SA  1580836289        64  25.02   37.27
#
#    Max Temp  Wind Speed
# 0   -18.400        5.70
# 1    62.708        2.25

# %% [markdown]
# ### Humidity Heatmap
# * Configure gmaps.
# * Use the Lat and Lng as locations and Humidity as the weight.
# * Add Heatmap layer to map.

# %%
gmaps.configure(api_key=q_key)
locations=weath_er[["Lat", "Lng"]]
weight=weath_er["Humidity"].astype(float)
fig=gmaps.figure()
heat_layer=gmaps.heatmap_layer(locations, weights=weight, 
                                 dissipating=True, max_intensity=10,
                                 point_radius=1)
fig.add_layer(heat_layer)
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %% [markdown]
# ### Create new DataFrame fitting weather criteria
# * Narrow down the cities to fit weather conditions.
# * Drop any rows will null values.

# %%
nice_weather=weath_er[weath_er['Max Temp'] > 65]
nicer_weather=nice_weather[nice_weather['Max Temp'] < 90]
nicest_weather=nicer_weather[nicer_weather['Humidity'] < 50]
best_weather=nicest_weather[nicest_weather['Wind Speed'] > 5]
best_weather
# Out:
#              City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 2      Miraflores          40      MX  1580836289        42  19.22  -98.81
# 18          Pisco          12      PE  1580836191        30 -13.70  -76.22
# 25      Busselton           0      AU  1580836304        25 -33.65  115.33
# 85        Aguimes          54      ES  1580836336        19  27.91  -15.45
# 248      Moussoro          17      TD  1580836438        10  13.64   16.49
# 251  Monte Patria           0      CL  1580836440        19 -30.69  -70.95
# 264    Nouadhibou           0      MR  1580836448        26  20.93  -17.03
# 334    San Rafael           5      AR  1580836487        34 -34.62  -68.33
# 342      Upington          40      ZA  1580836492        27 -28.45   21.26
# 387       Illapel           0      CL  1580836518        27 -31.63  -71.17
# 408        Ovalle           0      CL  1580836529        19 -30.60  -71.20
# ...

# %% [markdown]
# ### Hotel Map
# * Store into variable named `hotel_df`.
# * Add a "Hotel Name" column to the DataFrame.
# * Set parameters to search for hotels with 5000 meters.
# * Hit the Google Places API for each city's coordinates.
# * Store the first Hotel result into the DataFrame.
# * Plot markers on top of the heatmap.

# %%
hotel_df=best_weather
hotel_df['Hotel Name']=['','','','','','','','','','','','','','','']
# Out:
# C:\Users\phili\Anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
# NOTE: Do not change any of the code in this cell

# Using the template add the hotel marks to the heatmap
info_box_template = """
<dl>
<dt>Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
</dl>
"""
# Store the DataFrame Row
# NOTE: be sure to update with your DataFrame name
hotel_info = [info_box_template.format(**row) for index, row in narrowed_city_df.iterrows()]
locations = hotel_df[["Lat", "Lng"]]

# %%
# Add marker layer ontop of heat map


# Display Map
